# %%
import pandas as pd
import numpy as np

# %%
kredit_words = pd.read_csv('C:/Users/kiril/Desktop/cup_it/kredit_words.csv')
vklad_words = pd.read_csv('C:/Users/kiril/Desktop/cup_it/vklad_words.csv')
ipoteka_words = pd.read_csv('C:/Users/kiril/Desktop/cup_it/ipoteka_words.csv')
bisnez_words = pd.read_csv('C:/Users/kiril/Desktop/cup_it/bisnez_words.csv')
obslu_words = pd.read_csv('C:/Users/kiril/Desktop/cup_it/obslu_words.csv')
karta_words = pd.read_csv('C:/Users/kiril/Desktop/cup_it/karta_words.csv')
restruct_words = pd.read_csv('C:/Users/kiril/Desktop/cup_it/restruct_words.csv')
perevod_words = pd.read_csv('C:/Users/kiril/Desktop/cup_it/perevod_words.csv')
invest_words = pd.read_csv('C:/Users/kiril/Desktop/cup_it/invest_words.csv')

# %%
words = pd.concat([kredit_words['words'],vklad_words['words']],axis = 0)

# %%
words = pd.concat([words,invest_words['words']],axis = 0)

# %%
len(set(words))
# Out:
# 83

# %%
main_words = pd.DataFrame(columns = ['words'])

# %%
main_words['words'] = list(set(words))

# %%
main_words
# Out:
#                words
# 0            сказать
# 1             деньга
# 2            открыть
# 3                год
# 4           тинькофф
# 5              банка
# 6             кредит
# 7            договор
# 8           банкомат
# 9              время
# 10  рефинансирование
# 11               втб
# 12             рубль
# 13            клиент
# 14              курс
# 15            хотеть
# 16          сбербанк
# 17          работать
# 18             сумма
# 19           очередь
# 20            ставка
# 21    инвестиционный
# 22              банк
# 23           процент
# 24          открытие
# 25             карта
# 26              свой
# 27            решить
# 28          средство
# 29              счёт
# ..               ...
# 53            платёж
# 54          оформить
# 55             вклад
# 56          менеджер
# 57             месяц
# 58           сделать
# 59           человек
# 60            сделка
# 61           большой
# 62          ситуация
# 63              офис
# ...

# %%
main_words.to_csv(r'C:/Users/kiril/Desktop/cup_it/main_words.csv',index=False)
